# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
x = np.linspace(0,4*np.pi,200)
y1 = np.sin(x)
y2 = np.sin(x + 1)
y3 = np.sin(x + 2)
yt1 = np.sin(x)
yt2 = np.sin(x - 0.6)
yt3 = np.sin(x - 1.5)

# %%
fig = plt.figure(dpi=300)
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# set ticks
# ax.xaxis.set_ticks(np.pi*np.arange(0.5,4.0,0.5))
# ax.xaxis.set_ticks(np.pi*np.arange(0.5,4.0,0.5))
# ax.xaxis.set_ticklabels([r'$\pi/2$',r'$\pi$',r'$3 \pi /2$',r'$2 \pi$',r'$5 \pi /2$',r'$3 \pi$',r'$7 \pi /2$'])
ax.yaxis.set_ticklabels([])

# axis labels
ax.set_xlabel('$x$', loc='right')
ax.set_ylabel('$y(x)$', loc='top')
ax.plot(x,y1,x,y2,x,y3)

ax.legend(['t = t$_{1}$','t = t$_{2}$','t = t$_{3}$'])
plt.tight_layout()
fig.savefig('../wave_vs_space.png')

# %%
fig = plt.figure(dpi=300)
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# set ticks
# ax.xaxis.set_ticks(np.pi*np.arange(0.5,4.0,0.5))
# ax.xaxis.set_ticks(np.pi*np.arange(0.5,4.0,0.5))
# ax.xaxis.set_ticklabels([r'$\pi/2$',r'$\pi$',r'$3 \pi /2$',r'$2 \pi$',r'$5 \pi /2$',r'$3 \pi$',r'$7 \pi /2$'])
ax.yaxis.set_ticklabels([])

# axis labels
ax.set_xlabel('$t$', loc='right')
ax.set_ylabel('$y(t)$', loc='top')
ax.plot(x,yt1,x,yt2,x,yt3)

ax.legend(['x = x$_{1}$','x = x$_{2}$','x = x$_{3}$'])
plt.tight_layout()
fig.savefig('../wave_vs_time.png')
